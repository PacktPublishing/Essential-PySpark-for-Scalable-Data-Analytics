# %%
# %fs ls FileStore/shared_uploads/enriched_retail
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/shared_uploads/enriched_retail/_started_7801885220236706336</td><td>_started_7801885220236706336</td><td>0</td></tr></tbody></table></div>

# %%
retail_enriched = spark.read.option("header", True).csv("FileStore/shared_uploads/enriched_retail")
retail_enriched.createOrReplaceTempView("retail_enriched")
