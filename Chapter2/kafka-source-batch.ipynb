# %%
#from  pyspark.sql.functions import *
kafka_df = (spark.read
        .format("kafka")
        .option("kafka.bootstrap.servers", "localhost:9092")
        .option("subscribe", "wordcount")
        .option("startingOffsets", "earliest")
        .load()
        )
kafka_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+--------------------+---------+---------+------+--------------------+-------------+
#  key|               value|    topic|partition|offset|           timestamp|timestampType|
# +----+--------------------+---------+---------+------+--------------------+-------------+
# null|[4F 70 65 6E 4A 4...|wordcount|        0|     0|2020-12-23 17:28:...|            0|
# null|[2F 64 61 74 61 6...|wordcount|        0|     1|2020-12-23 17:28:...|            0|
# null|[20 20 22 59 6F 7...|wordcount|        0|     2|2020-12-23 17:28:...|            0|
# null|[2F 64 61 74 61 6...|wordcount|        0|     3|2020-12-23 17:28:...|            0|
# null|[20 20 22 59 6F 7...|wordcount|        0|     4|2020-12-23 17:28:...|            0|
# null|[57 65 64 20 44 6...|wordcount|        0|     5|2020-12-23 17:28:...|            0|
# null|[57 65 64 20 44 6...|wordcount|        0|     6|2020-12-23 17:28:...|            0|
# null|[57 65 64 20 44 6...|wordcount|        0|     7|2020-12-23 17:28:...|            0|
# null|[57 65 64 20 44 6...|wordcount|        0|     8|2020-12-23 17:28:...|            0|
# null|[2F 64 61 74 61 6...|wordcount|        0|     9|2020-12-23 17:28:...|            0|
# null|[20 20 22 59 6F 7...|wordcount|        0|    10|2020-12-23 17:28:...|            0|
# null|[2F 64 61 74 61 6...|wordcount|        0|    11|2020-12-23 17:28:...|            0|
# null|[20 20 22 59 6F 7...|wordcount|        0|    12|2020-12-23 17:28:...|            0|
# null|[57 65 64 20 44 6...|wordcount|        0|    13|2020-12-23 17:28:...|            0|
# null|[57 65 64 20 44 6...|wordcount|        0|    14|2020-12-23 17:28:...|            0|
# null|[57 65 64 20 44 6...|wordcount|        0|    15|2020-12-23 17:28:...|            0|
# null|[57 65 64 20 44 6...|wordcount|        0|    16|2020-12-23 17:28:...|            0|
# +----+--------------------+---------+---------+------+--------------------+-------------+
#
# </div>
