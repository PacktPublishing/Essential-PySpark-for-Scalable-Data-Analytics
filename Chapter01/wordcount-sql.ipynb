# %%
# %sql
DROP TABLE IF EXISTS word_counts;
CREATE TABLE word_counts (word STRING)
USING csv
OPTIONS("delimiter"=" ")
LOCATION "/databricks-datasets/README.md"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT word, COUNT(word) AS count
FROM word_counts
GROUP BY word
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>word</th><th>count</th></tr></thead><tbody><tr><td>sure</td><td>1</td></tr><tr><td>[http://creativecommons.org/licenses/by/4.0/legalcode](http://creativecommons.org/licenses/by/4.0/legalcode)</td><td>1</td></tr><tr><td>==========================</td><td>1</td></tr><tr><td>-------</td><td>1</td></tr><tr><td>Unless</td><td>1</td></tr><tr><td>Databricks</td><td>1</td></tr><tr><td>is</td><td>1</td></tr><tr><td>data</td><td>2</td></tr><tr><td>To</td><td>1</td></tr><tr><td>and</td><td>1</td></tr><tr><td>The</td><td>1</td></tr><tr><td>License</td><td>1</td></tr><tr><td>Contributions</td><td>1</td></tr><tr><td>to:</td><td>1</td></tr><tr><td>When</td><td>1</td></tr><tr><td>which</td><td>1</td></tr><tr><td>--------------------------</td><td>1</td></tr></tbody></table></div>
